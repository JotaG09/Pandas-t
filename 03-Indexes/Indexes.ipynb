# %%
people = {
    "first": ["Corey", 'Jane', 'John'],
    "last": ["Schafer", 'Doe', 'Doe'],
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df["email"]    # Acessando a coluna email
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: str

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
# Define o índice para a coluna email e modifica o DataFrame original
df.set_index("email", inplace=True)
# o inplace=True é necessário para modificar o DataFrame original, caso contrário,
# ele retornaria um novo DataFrame com o índice definido, mas não modificaria o DataFrame original.

# %%
df
# Out:
#                          first     last
# email
# CoreyMSchafer@gmail.com  Corey  Schafer
# JaneDoe@email.com         Jane      Doe
# JohnDoe@email.com         John      Doe

# %%
df.index
# Out:
# Index(['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com'], dtype='str', name='email')

# %%
df.loc["CoreyMSchafer@gmail.com", "last"] # Acessando o valor da coluna last para o índice "CoreyMSchafer@gmail.com"
# Out:
# 'Schafer'

# %%
df.iloc[1] # Acessando a segunda linha do DataFrame usando iloc, que é baseado em posição.
# Out:
# first    Jane
# last      Doe
# Name: JaneDoe@email.com, dtype: str

# %%
df.loc["JaneDoe@email.com"] # Acessando a linha correspondente ao índice "JaneDoe@email.com"
# Out:
# first    Jane
# last      Doe
# Name: JaneDoe@email.com, dtype: str

# %%
df.reset_index(inplace=True)    # Reseta o índice para o padrão numérico e modifica o DataFrame original
df
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe
